# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
X = dataset.iloc[['Sleep Duration']].values
y = dataset.iloc[['Quality of Sleep']].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(X_train, y_train,color = 'red')
plt.plot(X_train, model.predict(X_train), color ='blue')
plt.title('Sleep Index')
plt.xlabel('Sleep Duration')
plt.ylabel('Quality of Sleep')
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
plt.scatter(X_test, y_test,color = 'red')
plt.plot(X_test, model.predict(X_test), color ='blue')
plt.title('Sleep Index Predicted')
plt.xlabel('Sleep Duration')
plt.ylabel('Quality of Sleep')
plt.show()

# %% [markdown]
# # Accuracy Prediction

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

predictions_test = model.predict(X_test)

mse_test = mean_squared_error(y_test, y_pred)
rmse_test = np.sqrt(mse_test) # Calculate RMSE for test data

print(f"Test MSE: {mse_test}")
print(f"Test RMSE: {rmse_test}")
print(f"Test MAE: {mean_absolute_error(y_test, predictions_test)}")
print(f"Test R^2: {r2_score(y_test, predictions_test)}")
# Out:
# Test MSE: 0.29078847620496295
# Test RMSE: 0.5392480655551423
# Test MAE: 0.4117819675165533
# Test R^2: 0.7736389179832664
